# %%
import pandas as pd
import os

# %%
fit_data = pd.read_csv(r"E:\MiniProjects\takeout-20201010T082506Z-001\Daily Summaries.csv")

# %%
fit_data.tail()
# Out:
#             Date  Average weight (kg)  Max weight (kg)  Min weight (kg)  \
# 1089  2020-01-24                  NaN              NaN              NaN
# 1090  2020-01-25                  NaN              NaN              NaN
# 1091  2020-01-26                  NaN              NaN              NaN
# 1092  2020-01-27                  NaN              NaN              NaN
# 1093  2020-01-28                  NaN              NaN              NaN
#
#       Calories (kcal)  Heart Points  Heart Minutes  Low latitude (deg)  \
# 1089      1798.111193           NaN            NaN                 NaN
# 1090      1942.411520          34.0           34.0           12.353028
# 1091      1858.688403           6.0            6.0                 NaN
# 1092      1756.999984           NaN            NaN                 NaN
# 1093        80.809876           NaN            NaN                 NaN
#
#       Low longitude (deg)  High latitude (deg)  \
# 1089                  NaN                  NaN
# ...

# %%
fit_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 28 columns):
# Date                                1094 non-null object
# Average weight (kg)                 124 non-null float64
# Max weight (kg)                     124 non-null float64
# Min weight (kg)                     124 non-null float64
# Calories (kcal)                     932 non-null float64
# Heart Points                        449 non-null float64
# Heart Minutes                       449 non-null float64
# Low latitude (deg)                  367 non-null float64
# Low longitude (deg)                 367 non-null float64
# High latitude (deg)                 367 non-null float64
# High longitude (deg)                367 non-null float64
# Average heart rate (bpm)            0 non-null float64
# Max heart rate (bpm)                0 non-null float64
# Min heart rate (bpm)                0 non-null float64
# Step count                          1087 non-null float64
# ...

# %%
fit_data['Step count'].describe()
# Out:
# count     1087.000000
# mean      3315.275989
# std       2817.026648
# min         18.000000
# 25%        740.000000
# 50%       2813.000000
# 75%       5202.000000
# max      17550.000000
# Name: Step count, dtype: float64
